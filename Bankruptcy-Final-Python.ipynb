# %% [markdown]
# **Abstract:**
#
# The dataset is about bankruptcy prediction of Polish companies.The bankrupt companies were analyzed in the period 2000-2012, while the still operating companies were evaluated from 2007 to 2013.

# %% [markdown]
# **Data Set Characteristics**     : Multivariate
#
# **Attribute Characteristics**    : Real
#
# **Associated Tasks**             : Classification
#
# **Number of Instances**          : 10503
#
# **Area**                         : Business
#
# **Number of Attributes**         : 64
#
# **Date Donated**                 : 2016-04-11
#
# **Missing Values?**             : Yes
#
# **Number of Web Hits**          : 77671

# %% [markdown]
# **Data Set Information:**
#
# The dataset is about bankruptcy prediction of Polish companies. The data was collected from Emerging Markets Information Service (EMIS, [Web Link]), which is a database containing information on emerging markets around the world. The bankrupt companies were analyzed in the period 2000-2012, while the still operating companies were evaluated from 2007 to 2013.
# Basing on the collected data five classification cases were distinguished, that depends on the forecasting period:

# %% [markdown]
#   **1st Year** the data contains financial rates from 1st year of the forecasting period and corresponding class label that indicates bankruptcy status after 5 years. The data contains 7027 instances (financial statements), 271 represents bankrupted companies, 6756 firms that did not bankrupt in the forecasting period.

# %% [markdown]
#  **2nd Year**  the data contains financial rates from 2nd year of the forecasting period and corresponding class label that indicates bankruptcy status after 4 years. The data contains 10173 instances (financial statements), 400 represents bankrupted companies, 9773 firms that did not bankrupt in the forecasting period.

# %% [markdown]
#  **3rd Year**  the data contains financial rates from 3rd year of the forecasting period and corresponding class label that indicates bankruptcy status after 3 years. The data contains 10503 instances (financial statements), 495 represents bankrupted companies, 10008 firms that did not bankrupt in the forecasting period.

# %% [markdown]
#   **4th Year** the data contains financial rates from 4th year of the forecasting period and corresponding class label that indicates bankruptcy status after 2 years. The data contains 9792 instances (financial statements), 515 represents bankrupted companies, 9277 firms that did not bankrupt in the forecasting period.

# %% [markdown]
#   **5th Year**  the data contains financial rates from 5th year of the forecasting period and corresponding class label that indicates bankruptcy status after 1 year. The data contains 5910 instances (financial statements), 410 represents bankrupted companies, 5500 firms that did not bankrupt in the forecasting period.

# %% [markdown]
# **Attribute Information:**
#
# X1	net profit / total assets
#
# X2	total liabilities / total assets
#
# X3	working capital / total assets
#
# X4	current assets / short-term liabilities
#
# X5	[(cash + short-term securities + receivables - short-term liabilities) / (operating expenses - depreciation)] * 365
#
# X6	retained earnings / total assets
#
# X7	EBIT / total assets
#
# X8	book value of equity / total liabilities
#
# X9	sales / total assets
#
# X10	equity / total assets
#
# X11	(gross profit + extraordinary items + financial
# expenses) / total assets
#
# X12	gross profit / short-term liabilities
#
# X13	(gross profit + depreciation) / sales
#
# X14	(gross profit + interest) / total assets
#
# X15	(total liabilities * 365) / (gross profit + depreciation)
#
# X16	(gross profit + depreciation) / total liabilities
#
# X17	total assets / total liabilities
#
# X18	gross profit / total assets
#
# X19	gross profit / sales
#
# X20	(inventory * 365) / sales
#
# X21	sales (n) / sales (n-1)
#
# X22	profit on operating activities / total assets
#
# X23	net profit / sales
#
# X24	gross profit (in 3 years) / total assets
#
# X25	(equity - share capital) / total assets
#
# X26	(net profit + depreciation) / total liabilities
#
# X27	profit on operating activities / financial expenses
#
# X28	working capital / fixed assets
#
# X29	logarithm of total assets
#
# X30	(total liabilities - cash) / sales
#
# X31	(gross profit + interest) / sales
#
# X32	(current liabilities * 365) / cost of products sold
#
# X33	operating expenses / short-term liabilities
#
# X34	operating expenses / total liabilities
#
# X35	profit on sales / total assets
#
# X36	total sales / total assets
#
# X37	(current assets - inventories) / long-term liabilities
#
# X38	constant capital / total assets
#
# X39	profit on sales / sales
#
# X40	(current assets - inventory - receivables) / short-term liabilities
#
# X41	total liabilities / ((profit on operating activities + depreciation) * (12/365))
#
# X42	profit on operating activities / sales
#
# X43	rotation receivables + inventory turnover in days
#
# X44	(receivables * 365) / sales
#
# X45	net profit / inventory
#
# X46	(current assets - inventory) / short-term liabilities
#
# X47	(inventory * 365) / cost of products sold
# X48	EBITDA (profit on operating activities - depreciation) / total assets
#
# X49	EBITDA (profit on operating activities - depreciation) / sales
#
# X50	current assets / total liabilities
#
# X51	short-term liabilities / total assets
#
# X52	(short-term liabilities * 365) / cost of products sold)
#
# X53	equity / fixed assets
#
# X54	constant capital / fixed assets
#
# X55	working capital
#
# X56	(sales - cost of products sold) / sales
#
# X57	(current assets - inventory - short-term
# liabilities) / (sales - gross profit - depreciation)
#
# X58	total costs /total sales
#
# X59	long-term liabilities / equity
#
# X60	sales / inventory
#
# X61	sales / receivables
#
# X62	(short-term liabilities *365) / sales
#
# X63	sales / short-term liabilities
#
# X64	sales / fixed assets

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
from scipy.io import arff

# %%
first_year="1year.arff"
second_year="2year.arff"
third_year="3year.arff"
fourth_year="4year.arff"
fifth_year="5year.arff"

# %%
firstyear=arff.loadarff(first_year)
secondyear=arff.loadarff(second_year)
thirdyear=arff.loadarff(third_year)
fourthyear=arff.loadarff(fourth_year)
fifthyear=arff.loadarff(fifth_year)

# %%
firstyears=pd.DataFrame(firstyear[0])
secondyears=pd.DataFrame(secondyear[0])
thirdyears=pd.DataFrame(thirdyear[0])
forthyears=pd.DataFrame(fourthyear[0])
fifthyears=pd.DataFrame(fifthyear[0])

# %%
firstyears.head()
# Out:
#       Attr1    Attr2    Attr3   Attr4    Attr5    Attr6     Attr7    Attr8  \
# 0  0.200550  0.37951  0.39641  2.0472  32.3510  0.38825  0.249760  1.33050
# 1  0.209120  0.49988  0.47225  1.9447  14.7860  0.00000  0.258340  0.99601
# 2  0.248660  0.69592  0.26713  1.5548  -1.1523  0.00000  0.309060  0.43695
# 3  0.081483  0.30734  0.45879  2.4928  51.9520  0.14988  0.092704  1.86610
# 4  0.187320  0.61323  0.22960  1.4063  -7.3128  0.18732  0.187320  0.63070
#
#     Attr9   Attr10  ...    Attr56   Attr57   Attr58    Attr59  Attr60  Attr61  \
# 0  1.1389  0.50494  ...  0.121960  0.39718  0.87804  0.001924  8.4160  5.1372
# 1  1.6996  0.49788  ...  0.121300  0.42002  0.85300  0.000000  4.1486  3.2732
# 2  1.3090  0.30408  ...  0.241140  0.81774  0.76599  0.694840  4.9909  3.9510
# 3  1.0571  0.57353  ...  0.054015  0.14207  0.94598  0.000000  4.5746  3.6147
# 4  1.1559  0.38677  ...  0.134850  0.48431  0.86515  0.124440  6.3985  4.3158
#
#     Attr62  Attr63   Attr64  class
# ...

# %%
secondyears.head()
# Out:
#       Attr1    Attr2     Attr3   Attr4   Attr5     Attr6    Attr7    Attr8  \
# 0  0.202350  0.46500  0.240380  1.5171 -14.547  0.510690  0.25366  0.91816
# 1  0.030073  0.59563  0.186680  1.3382 -37.859 -0.000319  0.04167  0.67890
# 2  0.257860  0.29949  0.665190  3.2211  71.799  0.000000  0.31877  2.33200
# 3  0.227160  0.67850  0.042784  1.0828 -88.212  0.000000  0.28505  0.47384
# 4  0.085443  0.38039  0.359230  1.9444  21.731  0.187900  0.10823  1.37140
#
#      Attr9   Attr10  ...   Attr56    Attr57   Attr58   Attr59  Attr60  \
# 0  1.15190  0.42695  ...  0.13184  0.473950  0.86816  0.00024  8.5487
# 1  0.32356  0.40437  ...  0.12146  0.074369  0.87235  0.00000  1.5264
# 2  1.67620  0.69841  ...  0.16499  0.369210  0.81614  0.00000  4.3325
# 3  1.32410  0.32150  ...  0.29358  0.706570  0.78617  0.48456  5.2309
# 4  1.11260  0.52167  ...  0.10124  0.163790  0.89876  0.00000  5.7035
#
#     Attr61   Attr62   Attr63   Attr64  class
# 0  5.16550  107.740  3.38790   5.3440   b'0'
# ...

# %%
thirdyears.head()
# Out:
#       Attr1    Attr2    Attr3   Attr4    Attr5    Attr6     Attr7   Attr8  \
# 0  0.174190  0.41299  0.14371  1.3480 -28.9820  0.60383  0.219460  1.1225
# 1  0.146240  0.46038  0.28230  1.6294   2.5952  0.00000  0.171850  1.1721
# 2  0.000595  0.22612  0.48839  3.1599  84.8740  0.19114  0.004572  2.9881
# 3  0.024526  0.43236  0.27546  1.7833 -10.1050  0.56944  0.024526  1.3057
# 4  0.188290  0.41504  0.34231  1.9279 -58.2740  0.00000  0.233580  1.4094
#
#     Attr9   Attr10  ...    Attr56    Attr57   Attr58    Attr59  Attr60  \
# 0  1.1961  0.46359  ...  0.163960  0.375740  0.83604  0.000007  9.7145
# 1  1.6018  0.53962  ...  0.027516  0.271000  0.90108  0.000000  5.9882
# 2  1.0077  0.67566  ...  0.007639  0.000881  0.99236  0.000000  6.7742
# 3  1.0509  0.56453  ...  0.048398  0.043445  0.95160  0.142980  4.2286
# 4  1.3393  0.58496  ...  0.176480  0.321880  0.82635  0.073039  2.5912
#
#    Attr61   Attr62  Attr63  Attr64  class
# 0  6.2813   84.291  4.3303  4.0341   b'0'
# ...

# %%
forthyears.head()
# Out:
#       Attr1    Attr2    Attr3   Attr4    Attr5     Attr6     Attr7    Attr8  \
# 0  0.159290  0.46240  0.07773  1.1683  -44.853  0.467020  0.189480  0.82895
# 1 -0.127430  0.46243  0.26917  1.7517    7.597  0.000925 -0.127430  1.16250
# 2  0.070488  0.23570  0.52781  3.2393  125.680  0.163670  0.086895  2.87180
# 3  0.136760  0.40538  0.31543  1.8705   19.115  0.504970  0.136760  1.45390
# 4 -0.110080  0.69793  0.18878  1.2713  -15.344  0.000000 -0.110080  0.43282
#
#     Attr9   Attr10  ...    Attr56   Attr57   Attr58    Attr59   Attr60  \
# 0  1.1223  0.38330  ...  0.108990  0.41557  0.89101  0.001422   7.7928
# 1  1.2944  0.53757  ... -0.089372 -0.23704  1.06250  0.150410   5.4327
# 2  1.0574  0.67689  ...  0.054286  0.10413  0.94571  0.000000   7.1070
# 3  1.1144  0.58938  ...  0.102630  0.23203  0.89737  0.073024   6.1384
# 4  1.7350  0.30207  ...  0.439880 -0.36440  0.57153  0.000000  18.8010
#
#    Attr61   Attr62  Attr63   Attr64  class
# ...

# %%
fifthyears.head()
# Out:
#       Attr1    Attr2    Attr3   Attr4     Attr5     Attr6     Attr7    Attr8  \
# 0  0.088238  0.55472  0.01134  1.0205  -66.5200  0.342040  0.109490  0.57752
# 1 -0.006202  0.48465  0.23298  1.5998    6.1825  0.000000 -0.006202  1.06340
# 2  0.130240  0.22142  0.57751  3.6082  120.0400  0.187640  0.162120  3.05900
# 3 -0.089951  0.88700  0.26927  1.5222  -55.9920 -0.073957 -0.089951  0.12740
# 4  0.048179  0.55041  0.10765  1.2437  -22.9590  0.000000  0.059280  0.81682
#
#     Attr9   Attr10  ...    Attr56    Attr57   Attr58    Attr59   Attr60  \
# 0  1.0881  0.32036  ...  0.080955  0.275430  0.91905  0.002024   7.2711
# 1  1.2757  0.51535  ... -0.028591 -0.012035  1.00470  0.152220   6.0911
# 2  1.1415  0.67731  ...  0.123960  0.192290  0.87604  0.000000   8.7934
# 3  1.2754  0.11300  ...  0.418840 -0.796020  0.59074  2.878700   7.6524
# 4  1.5150  0.44959  ...  0.240400  0.107160  0.77048  0.139380  10.1180
#
#    Attr61   Attr62  Attr63  Attr64  class
# ...

# %%
print('Rows and columns in firstyears',firstyears.shape)
print('Rows and columns in secondyears',secondyears.shape)
print('Rows and columns in thirdyears',thirdyears.shape)
print('Rows and columns in fourthyears',forthyears.shape)
print('Rows and columns in fifthyears',fifthyears.shape)
# Out:
# Rows and columns in firstyears (7027, 65)
# Rows and columns in secondyears (10173, 65)
# Rows and columns in thirdyears (10503, 65)
# Rows and columns in fourthyears (9792, 65)
# Rows and columns in fifthyears (5910, 65)

# %%
firstyears["class"].value_counts()
# Out:
# b'0'    6756
# b'1'     271
# Name: class, dtype: int64

# %%
firstyears.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7027 entries, 0 to 7026
# Data columns (total 65 columns):
# Attr1     7024 non-null float64
# Attr2     7024 non-null float64
# Attr3     7024 non-null float64
# Attr4     6997 non-null float64
# Attr5     7019 non-null float64
# Attr6     7024 non-null float64
# Attr7     7024 non-null float64
# Attr8     7002 non-null float64
# Attr9     7026 non-null float64
# Attr10    7024 non-null float64
# Attr11    6988 non-null float64
# Attr12    6997 non-null float64
# Attr13    7027 non-null float64
# Attr14    7024 non-null float64
# Attr15    7025 non-null float64
# Attr16    7002 non-null float64
# Attr17    7002 non-null float64
# Attr18    7024 non-null float64
# Attr19    7027 non-null float64
# Attr20    7027 non-null float64
# Attr21    5405 non-null float64
# Attr22    7024 non-null float64
# Attr23    7027 non-null float64
# Attr24    6903 non-null float64
# Attr25    7024 non-null float64
# Attr26    7002 non-null float64
# ...

# %%
firstyears.describe()
# Out:
#              Attr1        Attr2        Attr3        Attr4         Attr5  \
# count  7024.000000  7024.000000  7024.000000  6997.000000  7.019000e+03
# mean      0.034660     0.560215     0.119969     2.629143 -2.631672e+02
# std       4.565504     5.350084     5.275459    13.257356  3.707460e+04
# min    -256.890000   -72.162000  -440.500000     0.000000 -2.722100e+06
# 25%       0.021182     0.296678     0.026968     1.063100 -4.449800e+01
# 50%       0.075802     0.482960     0.181275     1.502000 -5.373900e+00
# 75%       0.160268     0.680233     0.362548     2.460700  3.777050e+01
# max      94.280000   441.500000     1.000000  1017.800000  9.909000e+05
#
#              Attr6        Attr7        Attr8        Attr9       Attr10  ...  \
# count  7024.000000  7024.000000  7002.000000  7026.000000  7024.000000  ...
# mean      0.059712     0.313876     2.623996     5.552855     1.825832  ...
# std       6.051113     8.353274    18.708327   101.995448    33.836452  ...
# ...

# %%
firstyears["Year"]=1
secondyears["Year"]=2
thirdyears["Year"]=3
forthyears["Year"]=4
fifthyears["Year"]=5

# %%
joinfile=pd.concat([firstyears,secondyears,thirdyears,forthyears,fifthyears])

# %%
print(joinfile.shape)
joinfile.head()
# Out:
# (43405, 66)
#       Attr1    Attr2    Attr3   Attr4    Attr5    Attr6     Attr7    Attr8  \
# 0  0.200550  0.37951  0.39641  2.0472  32.3510  0.38825  0.249760  1.33050
# 1  0.209120  0.49988  0.47225  1.9447  14.7860  0.00000  0.258340  0.99601
# 2  0.248660  0.69592  0.26713  1.5548  -1.1523  0.00000  0.309060  0.43695
# 3  0.081483  0.30734  0.45879  2.4928  51.9520  0.14988  0.092704  1.86610
# 4  0.187320  0.61323  0.22960  1.4063  -7.3128  0.18732  0.187320  0.63070
#
#     Attr9   Attr10  ...   Attr57   Attr58    Attr59  Attr60  Attr61   Attr62  \
# 0  1.1389  0.50494  ...  0.39718  0.87804  0.001924  8.4160  5.1372   82.658
# 1  1.6996  0.49788  ...  0.42002  0.85300  0.000000  4.1486  3.2732  107.350
# 2  1.3090  0.30408  ...  0.81774  0.76599  0.694840  4.9909  3.9510  134.270
# 3  1.0571  0.57353  ...  0.14207  0.94598  0.000000  4.5746  3.6147   86.435
# 4  1.1559  0.38677  ...  0.48431  0.86515  0.124440  6.3985  4.3158  127.210
#
#    Attr63   Attr64  class  Year
# ...

# %%
joinfile['class'].value_counts()
# Out:
# b'0'    41314
# b'1'     2091
# Name: class, dtype: int64

# %%
class_tar=joinfile['class'].unique()
joinfile['class']=joinfile['class'].map({class_tar[0]:0,class_tar[1]:1})
class_df=pd.DataFrame({'class_counts':joinfile['class'].value_counts()})
joinfile['class'].value_counts()
# Out:
# 0    41314
# 1     2091
# Name: class, dtype: int64

# %%
joinfile.head()
# Out:
#       Attr1    Attr2    Attr3   Attr4    Attr5    Attr6     Attr7    Attr8  \
# 0  0.200550  0.37951  0.39641  2.0472  32.3510  0.38825  0.249760  1.33050
# 1  0.209120  0.49988  0.47225  1.9447  14.7860  0.00000  0.258340  0.99601
# 2  0.248660  0.69592  0.26713  1.5548  -1.1523  0.00000  0.309060  0.43695
# 3  0.081483  0.30734  0.45879  2.4928  51.9520  0.14988  0.092704  1.86610
# 4  0.187320  0.61323  0.22960  1.4063  -7.3128  0.18732  0.187320  0.63070
#
#     Attr9   Attr10  ...   Attr57   Attr58    Attr59  Attr60  Attr61   Attr62  \
# 0  1.1389  0.50494  ...  0.39718  0.87804  0.001924  8.4160  5.1372   82.658
# 1  1.6996  0.49788  ...  0.42002  0.85300  0.000000  4.1486  3.2732  107.350
# 2  1.3090  0.30408  ...  0.81774  0.76599  0.694840  4.9909  3.9510  134.270
# 3  1.0571  0.57353  ...  0.14207  0.94598  0.000000  4.5746  3.6147   86.435
# 4  1.1559  0.38677  ...  0.48431  0.86515  0.124440  6.3985  4.3158  127.210
#
#    Attr63   Attr64  class  Year
# ...

# %% [markdown]
# # Null Value Analysis

# %%
joinfile_class0=joinfile[joinfile["class"]==0]
joinfile_class1=joinfile[joinfile["class"]==1]

# %% [markdown]
# ### Class '0' Null Count

# %%
print(joinfile_class0.shape)
joinfile_class0.head()
# Out:
# (41314, 66)
#       Attr1    Attr2    Attr3   Attr4    Attr5    Attr6     Attr7    Attr8  \
# 0  0.200550  0.37951  0.39641  2.0472  32.3510  0.38825  0.249760  1.33050
# 1  0.209120  0.49988  0.47225  1.9447  14.7860  0.00000  0.258340  0.99601
# 2  0.248660  0.69592  0.26713  1.5548  -1.1523  0.00000  0.309060  0.43695
# 3  0.081483  0.30734  0.45879  2.4928  51.9520  0.14988  0.092704  1.86610
# 4  0.187320  0.61323  0.22960  1.4063  -7.3128  0.18732  0.187320  0.63070
#
#     Attr9   Attr10  ...   Attr57   Attr58    Attr59  Attr60  Attr61   Attr62  \
# 0  1.1389  0.50494  ...  0.39718  0.87804  0.001924  8.4160  5.1372   82.658
# 1  1.6996  0.49788  ...  0.42002  0.85300  0.000000  4.1486  3.2732  107.350
# 2  1.3090  0.30408  ...  0.81774  0.76599  0.694840  4.9909  3.9510  134.270
# 3  1.0571  0.57353  ...  0.14207  0.94598  0.000000  4.5746  3.6147   86.435
# 4  1.1559  0.38677  ...  0.48431  0.86515  0.124440  6.3985  4.3158  127.210
#
#    Attr63   Attr64  class  Year
# ...

# %%
list_class0_null=[]
for col1 in joinfile_class0.columns:
    values1=joinfile_class0[col1].isnull().sum()
    list_class0_null.append(values1)  

null_df_class0=pd.DataFrame({'Number of Nulls in class_0':list_class0_null,
                             'Null percentage of Class_0':(joinfile_class0.isnull().sum()/len(joinfile_class0.index))*100,
                              'Total Null percentage':(joinfile_class0.isnull().sum()/len(joinfile.index))*100
                             },index=joinfile_class0.columns)
null_df_class0.head()
# Out:
#        Number of Nulls in class_0  Null percentage of Class_0  \
# Attr1                           7                    0.016943
# Attr2                           7                    0.016943
# Attr3                           7                    0.016943
# Attr4                         128                    0.309822
# Attr5                          89                    0.215423
#
#        Total Null percentage
# Attr1               0.016127
# Attr2               0.016127
# Attr3               0.016127
# Attr4               0.294897
# Attr5               0.205046

# %%
null_df_class0=null_df_class0.sort_values('Number of Nulls in class_0',ascending=False)
null_df_class0=null_df_class0.loc[(null_df_class0!=0).any(axis=1)]
null_df_class0.head()
# Out:
#         Number of Nulls in class_0  Null percentage of Class_0  \
# Attr37                       18007                   43.585709
# Attr21                        5239                   12.680931
# Attr27                        2049                    4.959578
# Attr60                        1976                    4.782882
# Attr45                        1971                    4.770780
#
#         Total Null percentage
# Attr37              41.486004
# Attr21              12.070038
# Attr27               4.720654
# Attr60               4.552471
# Attr45               4.540952

# %% [markdown]
# ### Class '1' Null Count

# %%
list_class1_null=[]
for col2 in joinfile_class1.columns:
    values2=joinfile_class1[col2].isnull().sum()
    list_class1_null.append(values2)

null_df_class1=pd.DataFrame({'Number of Nulls in class_1':list_class1_null,
                             'Null percentage of Class_1':(joinfile_class1.isnull().sum()/len(joinfile_class1.index))*100,
                              'Total Null percentage':(joinfile_class1.isnull().sum()/len(joinfile.index))*100
                             },index=joinfile_class1.columns)
null_df_class1.head()
# Out:
#        Number of Nulls in class_1  Null percentage of Class_1  \
# Attr1                           1                    0.047824
# Attr2                           1                    0.047824
# Attr3                           1                    0.047824
# Attr4                           6                    0.286944
# Attr5                           0                    0.000000
#
#        Total Null percentage
# Attr1               0.002304
# Attr2               0.002304
# Attr3               0.002304
# Attr4               0.013823
# Attr5               0.000000

# %%
null_df_class1=null_df_class1.sort_values('Number of Nulls in class_1',ascending=False)
null_df_class1=null_df_class1.loc[(null_df_class1!=0).any(axis=1)]
null_df_class1.head()
# Out:
#         Number of Nulls in class_1  Null percentage of Class_1  \
# Attr37                         977                   46.724055
# Attr27                         715                   34.194165
# Attr21                         615                   29.411765
# Attr45                         176                    8.417025
# Attr60                         176                    8.417025
#
#         Total Null percentage
# Attr37               2.250893
# Attr27               1.647276
# Attr21               1.416887
# Attr45               0.405483
# Attr60               0.405483

# %%
excel_import=[]
excel_import.append(class_df)
excel_import.append(null_df_class0)
excel_import.append(null_df_class1)

writer=pd.ExcelWriter('Null_values_class.xlsx')
for n,df in enumerate(excel_import):
    df.to_excel(writer,'sheet %s' %(str(n+1)))
writer.save()

# %%
joinfile_class0.describe().T
# Out:
#           count         mean            std           min         25%  \
# Attr1   41307.0     0.053107       2.016219 -2.568900e+02    0.004947
# Attr2   41307.0     0.543903       4.528032 -4.308700e+02    0.263585
# Attr3   41307.0     0.157410       3.978791 -4.797300e+02    0.029964
# Attr4   41186.0     6.424485     302.743757 -4.531900e-02    1.069625
# Attr5   41225.0  -367.042710   62543.419918 -1.190300e+07  -46.357000
# Attr6   41307.0     0.000040       5.759398 -5.081200e+02    0.000000
# Attr7   41307.0     0.113939       5.379128 -5.174800e+02    0.007805
# Attr8   41225.0    12.946454     518.107833 -1.414100e+02    0.454050
# Attr9   41306.0     2.688728      64.499397 -1.215700e+00    1.020800
# Attr10  41307.0     0.677067      14.452781 -4.797300e+02    0.305935
# Attr11  41307.0     0.150183       4.929443 -1.894500e+02    0.018640
# Attr12  41186.0     1.377397      61.359912 -1.236400e+03    0.020536
# ...

# %% [markdown]
# # Dropping Null Values

# %%
joinfile_class1=joinfile_class1.drop(["Attr37","Attr21","Attr27","Attr60","Attr45"],axis=1)
joinfile_class0=joinfile_class0.drop(["Attr37","Attr21","Attr27","Attr60","Attr45"],axis=1)

# %%
joinfile_class0=joinfile_class0[~np.isnan(joinfile_class0).any(axis=1)]
joinfile_class1=joinfile_class1[~np.isnan(joinfile_class1).any(axis=1)]

# %%
final_df=pd.concat([joinfile_class0,joinfile_class1])
final_df.head()
# Out:
#        Attr1    Attr2     Attr3   Attr4    Attr5     Attr6     Attr7    Attr8  \
# 0   0.200550  0.37951  0.396410  2.0472  32.3510  0.388250  0.249760  1.33050
# 3   0.081483  0.30734  0.458790  2.4928  51.9520  0.149880  0.092704  1.86610
# 4   0.187320  0.61323  0.229600  1.4063  -7.3128  0.187320  0.187320  0.63070
# 8   0.009020  0.63202  0.053735  1.1263 -37.8420  0.000000  0.014434  0.58223
# 11 -0.027117  0.11148  0.119890  2.0754 -31.6430 -0.084883 -0.024300  7.67410
#
#       Attr9   Attr10  ...    Attr56    Attr57   Attr58    Attr59   Attr61  \
# 0   1.13890  0.50494  ...  0.121960  0.397180  0.87804  0.001924   5.1372
# 3   1.05710  0.57353  ...  0.054015  0.142070  0.94598  0.000000   3.6147
# 4   1.15590  0.38677  ...  0.134850  0.484310  0.86515  0.124440   4.3158
# 8   1.33320  0.36798  ...  0.180110  0.024512  0.84165  0.340940   4.2382
# 11  0.90732  0.85551  ... -0.102140 -0.031697  1.10210  0.000000  13.4610
#
#      Attr62  Attr63   Attr64  class  Year
# ...

# %%
print(final_df.shape)
print(joinfile.shape)
# Out:
# (40506, 61)
# (43405, 66)

# %% [markdown]
# # Outlier Analysis

# %%
final_df.describe().T
# Out:
#           count         mean            std           min         25%  \
# Attr1   40506.0     0.063332       0.517663 -3.205200e+01    0.003998
# Attr2   40506.0     0.510174       2.220895 -4.308700e+02    0.273012
# Attr3   40506.0     0.177848       0.561330 -7.206700e+01    0.019969
# Attr4   40506.0     3.576368      44.888262 -4.031100e-01    1.045900
# Attr5   40506.0  -327.989324   61100.322966 -1.190300e+07  -49.442750
# Attr6   40506.0     0.044908       3.821059 -1.174200e+02    0.000000
# Attr7   40506.0     0.079869       4.140135 -5.174800e+02    0.006390
# Attr8   40506.0     6.103318     238.990540 -3.735100e+00    0.435852
# Attr9   40506.0     2.005382      49.324424 -8.571900e-04    1.018600
# Attr10  40506.0     0.467956       1.787331 -7.144400e+01    0.297200
# Attr11  40506.0     0.110633       3.405370 -3.209000e+01    0.016364
# Attr12  40506.0     0.858915      27.646365 -1.236400e+03    0.016247
# ...

# %%
sns.boxplot(final_df.Attr5)
plt.show()
Q1=final_df['Attr5'].quantile(0.25)
Q3=final_df['Attr5'].quantile(0.75)

UL= (1.5*(Q3-Q1))+Q3
LL= Q1-(1.5*(Q3-Q1))

print(len(final_df))
print(len(final_df[(final_df.Attr5>UL) | (final_df.Attr5<LL)]))
# Out:
# 40506
# 5692

# %%
sns.boxplot(np.log(final_df.Attr1))
plt.show()
Q1=np.log(final_df['Attr1']).quantile(0.25)
Q3=np.log(final_df['Attr1']).quantile(0.75)

UL= (1.5*(Q3-Q1))+Q3
LL= Q1-(1.5*(Q3-Q1))
print(len(final_df))
print(len(np.log(final_df.Attr1).isnull()))
print(len(final_df[(np.log(final_df.Attr1)>UL) | (np.log(final_df.Attr1)<LL)]))
# Out:
# 40506
# 40506
# 1177

# %%
outlier=[]
outlier_percent=[]
for cols in final_df.columns:
    Q1=final_df[cols].quantile(0.25)
    Q3=final_df[cols].quantile(0.75)
    
    UL= (1.5*(Q3-Q1))+Q3
    LL= Q1-(1.5*(Q3-Q1))

    outliers=len(final_df[(final_df[cols]>UL) | (final_df[cols]<LL)])
    outlier.append(outliers)
    outlier_percent.append((outliers/len(final_df))*100)
    
    
outlier_df=pd.DataFrame({'outliers':outlier,'outlier_percentage':outlier_percent},index=final_df.columns)
outlier_df.sort_values(by='outlier_percentage',ascending=False)
# Out:
#         outliers  outlier_percentage
# Attr6       9345           23.070656
# Attr55      6848           16.906137
# Attr15      6752           16.669135
# Attr41      6547           16.163038
# Attr59      6144           15.168123
# Attr5       5692           14.052239
# Attr28      5618           13.869550
# Attr54      5596           13.815237
# Attr53      5407           13.348640
# Attr64      5280           13.035106
# Attr12      5198           12.832667
# Attr23      5162           12.743791
# Attr57      5017           12.385819
# Attr40      4909           12.119192
# Attr49      4793           11.832815
# Attr26      4758           11.746408
# Attr19      4716           11.642720
# Attr31      4694           11.588407
# Attr16      4661           11.506937
# Attr56      4575           11.294623
# Attr58      4490           11.084778
# Attr39      4331           10.692243
# Attr8       4269           10.539179
# Attr17      4261           10.519429
# ...

# %%
final_df.shape
# Out:
# (40506, 61)

# %%
final_df1=final_df.copy()
print(final_df1.shape)
# Out:
# (40506, 61)

# %%
print(final_df1[(final_df1['Attr1']<max(final_df1['Attr1']))].shape)
# Out:
# (40505, 61)

# %%
print(final_df1.drop(final_df1[final_df1['Attr1']==max(final_df1['Attr1'])].index).shape)
# Out:
# (40502, 61)

# %%
final_df1[final_df1['Attr1']==max(final_df1['Attr1'])].index
# Out:
# Int64Index([4351], dtype='int64')

# %% [markdown]
# ### Treating Outlier with min and max

# %%
max_cols=['Attr1','Attr4','Attr7','Attr8','Attr10','Attr11','Attr12','Attr16','Attr17','Attr19','Attr20','Attr22','Attr23',
          'Attr26','Attr28','Attr31','Attr32','Attr33','Attr34','Attr35','Attr36','Attr38','Attr40','Attr41','Attr43','Attr44',
          'Attr46','Attr47','Attr48','Attr50','Attr51','Attr52','Attr53','Attr54','Attr55','Attr58','Attr59','Attr61','Attr62',
          'Attr63','Attr64','Attr14','Attr15','Attr18','Attr39','Attr42']
min_cols=['Attr2','Attr3','Attr5','Attr49','Attr56','Attr57','Attr14','Attr15','Attr18','Attr39','Attr42']


for i in max_cols:
    final_df1=final_df1[(final_df1[i]<max(final_df1[i]))]

for i in min_cols:
    final_df1=final_df1[(final_df1[i]>min(final_df1[i]))]

#for i in max_cols:
#    final_df1.drop(final_df1[final_df1[i]==max(final_df1[i])].index,inplace=True)

#for i in min_cols:
#    final_df1.drop(final_df1[final_df1[i]==min(final_df1[i])].index,inplace=True)


final_df1.shape
# Out:
# (40447, 61)

# %%
sns.pairplot(final_df1.iloc[:,11:21])

# %% [raw]
# Still few columns have outliers that may affect the model.

# %% [markdown]
# ### Manual Outlier treatment

# %%
final_df1=final_df1[(final_df1['Attr9']<300) & (final_df1['Attr12']<1000) & (final_df1['Attr12']>-1000)]
final_df1=final_df1[(final_df1['Attr13']<2000) & (final_df1['Attr15']>-4000000) & (final_df1['Attr17']<2000)]
final_df1=final_df1[(final_df1['Attr18']<40) & (final_df1['Attr19']>-300) & (final_df1['Attr20']<20000)]
final_df1=final_df1[(final_df1['Attr23']>-300) & (final_df1['Attr26']<400) & (final_df1['Attr28']>-4000) & (final_df1['Attr28']<4000)]
final_df1=final_df1[(final_df1['Attr32']<2000000) & (final_df1['Attr35']>-8) & (final_df1['Attr39']>-300)]
final_df1=final_df1[(final_df1['Attr40']<500) & (final_df1['Attr41']<4000) & (final_df1['Attr42']>-300)]
final_df1=final_df1[(final_df1['Attr43']<200000) & (final_df1['Attr43']<200000) & (final_df1['Attr49']>-300)]
final_df1=final_df1[(final_df1['Attr50']<600) & (final_df1['Attr52']<1000) & (final_df1['Attr53']>-2000) & (final_df1['Attr53']<4000)]
final_df1=final_df1[(final_df1['Attr53']>-2000) & (final_df1['Attr54']<4000) & (final_df1['Attr56']>-200) & (final_df1['Attr56']<100)]
final_df1=final_df1[(final_df1['Attr57']>-750) & (final_df1['Attr57']<500) & (final_df1['Attr58']<250)]
final_df1=final_df1[(final_df1['Attr59']<2000) & (final_df1['Attr61']<6000) & (final_df1['Attr62']<400000) & (final_df1['Attr64']>-8000)]

# %%
final_df1.shape
# Out:
# (40410, 61)

# %%
sns.pairplot(final_df1.iloc[:,11:21])

# %% [markdown]
# # EDA

# %%
joinfile['Null_value_sum']=joinfile.isnull().sum(axis=1)
joinfile.head()
# Out:
#       Attr1    Attr2    Attr3   Attr4    Attr5    Attr6     Attr7    Attr8  \
# 0  0.200550  0.37951  0.39641  2.0472  32.3510  0.38825  0.249760  1.33050
# 1  0.209120  0.49988  0.47225  1.9447  14.7860  0.00000  0.258340  0.99601
# 2  0.248660  0.69592  0.26713  1.5548  -1.1523  0.00000  0.309060  0.43695
# 3  0.081483  0.30734  0.45879  2.4928  51.9520  0.14988  0.092704  1.86610
# 4  0.187320  0.61323  0.22960  1.4063  -7.3128  0.18732  0.187320  0.63070
#
#     Attr9   Attr10  ...   Attr58    Attr59  Attr60  Attr61   Attr62  Attr63  \
# 0  1.1389  0.50494  ...  0.87804  0.001924  8.4160  5.1372   82.658  4.4158
# 1  1.6996  0.49788  ...  0.85300  0.000000  4.1486  3.2732  107.350  3.4000
# 2  1.3090  0.30408  ...  0.76599  0.694840  4.9909  3.9510  134.270  2.7185
# 3  1.0571  0.57353  ...  0.94598  0.000000  4.5746  3.6147   86.435  4.2228
# 4  1.1559  0.38677  ...  0.86515  0.124440  6.3985  4.3158  127.210  2.8692
#
#     Attr64  class  Year  Null_value_sum
# ...

# %%
plt.hist(joinfile[joinfile['class']==0]['Null_value_sum'])
plt.xlabel('Number of null Values')
plt.ylabel('Number of companies')
plt.show()
plt.hist(joinfile[joinfile['class']==1]['Null_value_sum'])
plt.xlabel('Number of null Values')
plt.ylabel('Number of companies')
plt.show()

# %%
pd.crosstab(joinfile['Year'],joinfile['class'])
# Out:
# class      0    1
# Year
# 1       6756  271
# 2       9773  400
# 3      10008  495
# 4       9277  515
# 5       5500  410

# %%
pd.crosstab(joinfile['Null_value_sum'].sum(),joinfile['Year'])
# Out:
# Year      1      2      3     4     5
# row_0
# 41322  7027  10173  10503  9792  5910

# %%
#joinfile.to_csv('joinfile.csv')

# %% [markdown]
# # Building Base Model

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
X=final_df1.drop(["Year","class"],axis=1)
y=final_df1["class"]

# %%
Xtrain,Xtest,ytrain,ytest=train_test_split(X,y,test_size=0.3,random_state=0)
ytest.value_counts()
# Out:
# 0    11516
# 1      607
# Name: class, dtype: int64

# %%
lr=LogisticRegression()
lr.fit(Xtrain,ytrain)
ypred_lr=lr.predict(Xtest)
print(metrics.confusion_matrix(ytest,ypred_lr))
print(metrics.classification_report(ytest,ypred_lr))
# Out:
# [[11390   126]
#  [  598     9]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97     11516
#            1       0.07      0.01      0.02       607
#
#     accuracy                           0.94     12123
#    macro avg       0.51      0.50      0.50     12123
# weighted avg       0.91      0.94      0.92     12123

# %%
knn=KNeighborsClassifier()
knn.fit(Xtrain,ytrain)
ypred_knn=knn.predict(Xtest)
print(metrics.confusion_matrix(ytest,ypred_knn))
print(metrics.classification_report(ytest,ypred_knn))
# Out:
# [[11479    37]
#  [  605     2]]
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97     11516
#            1       0.05      0.00      0.01       607
#
#     accuracy                           0.95     12123
#    macro avg       0.50      0.50      0.49     12123
# weighted avg       0.90      0.95      0.92     12123

# %%
xgb=XGBClassifier()
xgb.fit(Xtrain,ytrain)
ypred_xgb=knn.predict(Xtest)
print(metrics.confusion_matrix(ytest,ypred_xgb))
print(metrics.classification_report(ytest,ypred_xgb))
# Out:
# [[11479    37]
#  [  605     2]]
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97     11516
#            1       0.05      0.00      0.01       607
#
#     accuracy                           0.95     12123
#    macro avg       0.50      0.50      0.49     12123
# weighted avg       0.90      0.95      0.92     12123

# %%
dt=DecisionTreeClassifier()
dt.fit(Xtrain,ytrain)
ypred_dt=dt.predict(Xtest)
print(metrics.confusion_matrix(ytest,ypred_dt))
print(metrics.classification_report(ytest,ypred_dt))
# Out:
# [[11076   440]
#  [  400   207]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.96     11516
#            1       0.32      0.34      0.33       607
#
#     accuracy                           0.93     12123
#    macro avg       0.64      0.65      0.65     12123
# weighted avg       0.93      0.93      0.93     12123

# %%
rf=RandomForestClassifier()
rf.fit(Xtrain,ytrain)
ypred_rf=rf.predict(Xtest)
print(metrics.confusion_matrix(ytest,ypred_rf))
print(metrics.classification_report(ytest,ypred_rf))
# Out:
# [[11478    38]
#  [  572    35]]
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97     11516
#            1       0.48      0.06      0.10       607
#
#     accuracy                           0.95     12123
#    macro avg       0.72      0.53      0.54     12123
# weighted avg       0.93      0.95      0.93     12123

# %% [markdown]
# # Model with SMOTE

# %%
from imblearn.over_sampling import SMOTE
smt=SMOTE()
X_train,y_train=smt.fit_sample(Xtrain,ytrain)
print(np.bincount(y_train))
# Out:
# [26951 26951]

# %%
dt_smote=DecisionTreeClassifier()
dt_smote.fit(X_train,y_train)
ypred_dt_smote=dt_smote.predict(Xtest)
print(metrics.confusion_matrix(ytest,ypred_dt_smote))
print(metrics.classification_report(ytest,ypred_dt_smote))
# Out:
# [[10316  1200]
#  [  326   281]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.90      0.93     11516
#            1       0.19      0.46      0.27       607
#
#     accuracy                           0.87     12123
#    macro avg       0.58      0.68      0.60     12123
# weighted avg       0.93      0.87      0.90     12123

# %%
rf_smote=RandomForestClassifier()
rf_smote.fit(X_train,y_train)
ypred_rf_smote=rf_smote.predict(Xtest)
print(metrics.confusion_matrix(ytest,ypred_rf_smote))
print(metrics.classification_report(ytest,ypred_rf_smote))
# Out:
# [[11053   463]
#  [  405   202]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96     11516
#            1       0.30      0.33      0.32       607
#
#     accuracy                           0.93     12123
#    macro avg       0.63      0.65      0.64     12123
# weighted avg       0.93      0.93      0.93     12123

# %% [markdown]
# # Model with NearMiss

# %%
from imblearn.under_sampling import NearMiss
nm=NearMiss()
X_train_nm,y_train_nm=nm.fit_sample(Xtrain,ytrain)
print(np.bincount(y_train))
# Out:
# [26951 26951]

# %%
dt_nm=DecisionTreeClassifier()
dt_nm.fit(X_train_nm,y_train_nm)
ypred_dt_nm=dt_nm.predict(Xtest)
print(metrics.confusion_matrix(ytest,ypred_dt_nm))
print(metrics.classification_report(ytest,ypred_dt_nm))
# Out:
# [[2769 8747]
#  [  74  533]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.24      0.39     11516
#            1       0.06      0.88      0.11       607
#
#     accuracy                           0.27     12123
#    macro avg       0.52      0.56      0.25     12123
# weighted avg       0.93      0.27      0.37     12123

# %%
rf_nm=RandomForestClassifier()
rf_nm.fit(X_train_nm,y_train_nm)
ypred_rf_nm=rf_nm.predict(Xtest)
print(metrics.confusion_matrix(ytest,ypred_rf_nm))
print(metrics.classification_report(ytest,ypred_rf_nm))
# Out:
# [[4012 7504]
#  [  90  517]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.35      0.51     11516
#            1       0.06      0.85      0.12       607
#
#     accuracy                           0.37     12123
#    macro avg       0.52      0.60      0.32     12123
# weighted avg       0.93      0.37      0.49     12123

# %% [markdown]
# # Imputation

# %%
from sklearn.preprocessing import Imputer

# %%
median_imputer=Imputer(missing_values=np.nan, strategy='median')
imputed_med=median_imputer.fit_transform(joinfile)
# Out:
# C:\Users\surendhar\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
imputed_med_df=pd.DataFrame(imputed_med,columns=joinfile.columns)

# %%
imputed_med_df.head()
# Out:
#       Attr1    Attr2    Attr3   Attr4    Attr5    Attr6     Attr7    Attr8  \
# 0  0.200550  0.37951  0.39641  2.0472  32.3510  0.38825  0.249760  1.33050
# 1  0.209120  0.49988  0.47225  1.9447  14.7860  0.00000  0.258340  0.99601
# 2  0.248660  0.69592  0.26713  1.5548  -1.1523  0.00000  0.309060  0.43695
# 3  0.081483  0.30734  0.45879  2.4928  51.9520  0.14988  0.092704  1.86610
# 4  0.187320  0.61323  0.22960  1.4063  -7.3128  0.18732  0.187320  0.63070
#
#     Attr9   Attr10  ...   Attr58    Attr59  Attr60  Attr61   Attr62  Attr63  \
# 0  1.1389  0.50494  ...  0.87804  0.001924  8.4160  5.1372   82.658  4.4158
# 1  1.6996  0.49788  ...  0.85300  0.000000  4.1486  3.2732  107.350  3.4000
# 2  1.3090  0.30408  ...  0.76599  0.694840  4.9909  3.9510  134.270  2.7185
# 3  1.0571  0.57353  ...  0.94598  0.000000  4.5746  3.6147   86.435  4.2228
# 4  1.1559  0.38677  ...  0.86515  0.124440  6.3985  4.3158  127.210  2.8692
#
#     Attr64  class  Year  Null_value_sum
# ...

# %%
for i in max_cols:
    imputed_med_df=imputed_med_df[(imputed_med_df[i]<max(imputed_med_df[i]))]

for i in min_cols:
    imputed_med_df=imputed_med_df[(imputed_med_df[i]>min(imputed_med_df[i]))]

imputed_med_df=imputed_med_df[(imputed_med_df['Attr9']<300) & (imputed_med_df['Attr12']<1000) & (imputed_med_df['Attr12']>-1000)]
imputed_med_df=imputed_med_df[(imputed_med_df['Attr13']<2000) & (imputed_med_df['Attr15']>-4000000) & (imputed_med_df['Attr17']<2000)]
imputed_med_df=imputed_med_df[(imputed_med_df['Attr18']<40) & (imputed_med_df['Attr19']>-300) & (imputed_med_df['Attr20']<20000)]
imputed_med_df=imputed_med_df[(imputed_med_df['Attr23']>-300) & (imputed_med_df['Attr26']<400) & (imputed_med_df['Attr28']>-4000) & (imputed_med_df['Attr28']<4000)]
imputed_med_df=imputed_med_df[(imputed_med_df['Attr32']<2000000) & (imputed_med_df['Attr35']>-8) & (imputed_med_df['Attr39']>-300)]
imputed_med_df=imputed_med_df[(imputed_med_df['Attr40']<500) & (imputed_med_df['Attr41']<4000) & (imputed_med_df['Attr42']>-300)]
imputed_med_df=imputed_med_df[(imputed_med_df['Attr43']<200000) & (imputed_med_df['Attr43']<200000) & (imputed_med_df['Attr49']>-300)]
imputed_med_df=imputed_med_df[(imputed_med_df['Attr50']<600) & (imputed_med_df['Attr52']<1000) & (imputed_med_df['Attr53']>-2000) & (imputed_med_df['Attr53']<4000)]
imputed_med_df=imputed_med_df[(imputed_med_df['Attr53']>-2000) & (imputed_med_df['Attr54']<4000) & (imputed_med_df['Attr56']>-200) & (imputed_med_df['Attr56']<100)]
imputed_med_df=imputed_med_df[(imputed_med_df['Attr57']>-750) & (imputed_med_df['Attr57']<500) & (imputed_med_df['Attr58']<250)]
imputed_med_df=imputed_med_df[(imputed_med_df['Attr59']<2000) & (imputed_med_df['Attr61']<6000) & (imputed_med_df['Attr62']<400000) & (imputed_med_df['Attr64']>-8000)]

# %%
Xi=imputed_med_df.drop(['class','Year','Null_value_sum'],axis=1)
yi=imputed_med_df['class']
Xitrain,Xitest,yitrain,yitest=train_test_split(Xi,yi,test_size=0.3,random_state=0)

# %%
dti=DecisionTreeClassifier()
dti.fit(Xitrain,yitrain)
ypred_dti=dti.predict(Xitest)
print(metrics.confusion_matrix(yitest,ypred_dti))
print(metrics.classification_report(yitest,ypred_dti))
# Out:
# [[11968   360]
#  [  288   354]]
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.97      0.97     12328
#          1.0       0.50      0.55      0.52       642
#
#     accuracy                           0.95     12970
#    macro avg       0.74      0.76      0.75     12970
# weighted avg       0.95      0.95      0.95     12970

# %% [markdown]
# #### Giving more metrics value when compared to base model

# %%
rfi=RandomForestClassifier()
rfi.fit(Xitrain,yitrain)
ypred_rfi=rfi.predict(Xitest)
print(metrics.confusion_matrix(yitest,ypred_rfi))
print(metrics.classification_report(yitest,ypred_rfi))
# Out:
# [[12288    40]
#  [  498   144]]
#               precision    recall  f1-score   support
#
#          0.0       0.96      1.00      0.98     12328
#          1.0       0.78      0.22      0.35       642
#
#     accuracy                           0.96     12970
#    macro avg       0.87      0.61      0.66     12970
# weighted avg       0.95      0.96      0.95     12970

# %% [markdown]
# # Feature Selection

# %% [markdown]
# ### Correlation Value for target

# %%
imputed_med_df.corr()['class'].sort_values()
# Out:
# Attr35           -0.107240
# Attr22           -0.079180
# Attr11           -0.073754
# Attr7            -0.064922
# Attr18           -0.064922
# Attr14           -0.064922
# Attr1            -0.063419
# Attr29           -0.055529
# Attr25           -0.046820
# Attr48           -0.043465
# Attr10           -0.042436
# Attr38           -0.042252
# Attr3            -0.039092
# Attr6            -0.034008
# Attr16           -0.026555
# Attr55           -0.023806
# Attr39           -0.020763
# Attr26           -0.020563
# Attr12           -0.020350
# Attr56           -0.020333
# Attr57           -0.020132
# Attr13           -0.012669
# Attr19           -0.012380
# Attr23           -0.012245
# Attr24           -0.012132
# Attr31           -0.011256
# Attr42           -0.010279
# Attr49           -0.009796
# Attr53           -0.007773
# Attr27           -0.006756
#                     ...
# Attr21           -0.002362
# Attr60           -0.002016
# Attr63           -0.001374
# ...

# %% [markdown]
# # VIF

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = [variance_inflation_factor(Xi.values, i) for i in range(Xi.shape[1])]

# %%
vif_df=pd.DataFrame({'VIF': vif[:]}, index=Xi.columns).sort_values('VIF',ascending=False)
print(vif_df[vif_df['VIF']<=5].sort_index().shape)
vif_df[vif_df['VIF']<=5].sort_index()
# Out:
# (22, 1)
#              VIF
# Attr11  3.832652
# Attr12  2.254084
# Attr15  1.049775
# Attr21  1.000670
# Attr24  2.225156
# Attr27  1.006354
# Attr30  4.065803
# Attr34  4.994483
# Attr37  1.002500
# Attr40  4.922956
# Attr41  1.002509
# Attr45  1.385862
# Attr47  2.071471
# Attr48  3.181631
# Attr5   1.100597
# Attr55  1.051934
# Attr57  1.170931
# Attr58  2.979078
# Attr59  1.173498
# Attr60  1.383695
# Attr61  1.079455
# Attr64  1.891671

# %% [markdown]
# Model with above attributes gives low precision and recall

# %% [markdown]
# ### RFE

# %% [markdown]
# #### Decision Tree

# %%
from sklearn.feature_selection import RFE

# %%
rfe=RFE(dti,n_features_to_select=15)
rfe.fit(Xitrain,yitrain)
# Out:
# RFE(estimator=DecisionTreeClassifier(class_weight=None, criterion='gini',
#                                      max_depth=None, max_features=None,
#                                      max_leaf_nodes=None,
#                                      min_impurity_decrease=0.0,
#                                      min_impurity_split=None,
#                                      min_samples_leaf=1, min_samples_split=2,
#                                      min_weight_fraction_leaf=0.0,
#                                      presort=False, random_state=None,
#                                      splitter='best'),
#     n_features_to_select=15, step=1, verbose=0)

# %%
dt_rfe=pd.DataFrame({'Ranks':rfe.ranking_},index=Xitrain.columns).sort_values('Ranks')

# %%
dt_rfe[dt_rfe['Ranks']==1].index
# Out:
# Index(['Attr55', 'Attr27', 'Attr56', 'Attr41', 'Attr20', 'Attr58', 'Attr28',
#        'Attr46', 'Attr34', 'Attr15', 'Attr5', 'Attr61', 'Attr40', 'Attr35',
#        'Attr6'],
#       dtype='object')

# %%
Xtrain_rfe=Xitrain[dt_rfe[dt_rfe['Ranks']==1].index]
Xtest_rfe=Xitest[dt_rfe[dt_rfe['Ranks']==1].index]

# %%
dt_rfe=DecisionTreeClassifier()
dt_rfe.fit(Xtrain_rfe,yitrain)
ypred_dt_rfe=dt_rfe.predict(Xtest_rfe)
print(metrics.confusion_matrix(yitest,ypred_dt_rfe))
print(metrics.classification_report(yitest,ypred_dt_rfe)) # top 15 features is giving more precision and recall
# Out:
# [[12014   314]
#  [  291   351]]
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.97      0.98     12328
#          1.0       0.53      0.55      0.54       642
#
#     accuracy                           0.95     12970
#    macro avg       0.75      0.76      0.76     12970
# weighted avg       0.95      0.95      0.95     12970

# %% [markdown]
# #### RFE with SMOTE

# %%
smt=SMOTE()
Xtrain_smote,ytrain_smote=smt.fit_sample(Xtrain_rfe,yitrain)


dt_rfe_smote=DecisionTreeClassifier()
dt_rfe_smote.fit(Xtrain_smote,ytrain_smote)
ypred_dt_rfe_smote=dt_rfe_smote.predict(Xtest_rfe)
print(metrics.confusion_matrix(yitest,ypred_dt_rfe_smote))
print(metrics.classification_report(yitest,ypred_dt_rfe_smote))
# Out:
# [[11129  1199]
#  [  238   404]]
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.90      0.94     12328
#          1.0       0.25      0.63      0.36       642
#
#     accuracy                           0.89     12970
#    macro avg       0.62      0.77      0.65     12970
# weighted avg       0.94      0.89      0.91     12970

# %%
nm=NearMiss()
Xtrain_nm,ytrain_nm=nm.fit_sample(Xtrain_rfe,yitrain)


dt_rfe_nm=DecisionTreeClassifier()
dt_rfe_nm.fit(Xtrain_nm,ytrain_nm)
ypred_dt_rfe_nm=dt_rfe_nm.predict(Xtest_rfe)
print(metrics.confusion_matrix(yitest,ypred_dt_rfe_nm))
print(metrics.classification_report(yitest,ypred_dt_rfe_nm))
# Out:
# [[2827 9501]
#  [  78  564]]
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.23      0.37     12328
#          1.0       0.06      0.88      0.11       642
#
#     accuracy                           0.26     12970
#    macro avg       0.51      0.55      0.24     12970
# weighted avg       0.93      0.26      0.36     12970

# %% [markdown]
# #### Random Forest

# %%
rfe1=RFE(rfi,n_features_to_select=15)
rfe1.fit(Xitrain,yitrain)
rf_rfe_df=pd.DataFrame({'Ranks':rfe1.ranking_},index=Xitrain.columns).sort_values('Ranks')
Xtrain_rfe1=Xitrain[rf_rfe_df[rf_rfe_df['Ranks']==1].index]
Xtest_rfe1=Xitest[rf_rfe_df[rf_rfe_df['Ranks']==1].index]

rf_rfe=RandomForestClassifier()
rf_rfe.fit(Xtrain_rfe1,yitrain)
ypred_rf_rfe=rf_rfe.predict(Xtest_rfe1)
print(metrics.confusion_matrix(yitest,ypred_rf_rfe))
print(metrics.classification_report(yitest,ypred_rf_rfe))
# Out:
# [[12303    25]
#  [  418   224]]
#               precision    recall  f1-score   support
#
#          0.0       0.97      1.00      0.98     12328
#          1.0       0.90      0.35      0.50       642
#
#     accuracy                           0.97     12970
#    macro avg       0.93      0.67      0.74     12970
# weighted avg       0.96      0.97      0.96     12970

# %%
from imblearn.ensemble import BalancedBaggingClassifier

# %%
bbc=BalancedBaggingClassifier()

bbc.fit(Xtrain_rfe1,yitrain)
ypred_bbc=bbc.predict(Xtest_rfe1)
print(metrics.confusion_matrix(yitest,ypred_bbc))
print(metrics.classification_report(yitest,ypred_bbc))
# Out:
# [[11210  1118]
#  [  150   492]]
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.91      0.95     12328
#          1.0       0.31      0.77      0.44       642
#
#     accuracy                           0.90     12970
#    macro avg       0.65      0.84      0.69     12970
# weighted avg       0.95      0.90      0.92     12970

# %%
from sklearn.ensemble import VotingClassifier

# %%
stack_model1=VotingClassifier([('RF_rfe',rf_rfe),('BBC',bbc)],voting='soft')
stack_model1.fit(Xtrain_rfe1,yitrain)
ypred_stack1=stack_model1.predict(Xtest_rfe1)
print(metrics.confusion_matrix(yitest,ypred_stack1))
print(metrics.classification_report(yitest,ypred_stack1))
# Out:
# [[12213   115]
#  [  281   361]]
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.99      0.98     12328
#          1.0       0.76      0.56      0.65       642
#
#     accuracy                           0.97     12970
#    macro avg       0.87      0.78      0.81     12970
# weighted avg       0.97      0.97      0.97     12970

# %%
print(metrics.roc_auc_score(yitest,ypred_stack1))
# Out:
# 0.7764884688706003

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gbc=GradientBoostingClassifier()

# %%
gbc.fit(Xtrain_rfe1,yitrain)
ypred_gbc=gbc.predict(Xtest_rfe1)
print(metrics.confusion_matrix(yitest,ypred_gbc))
print(metrics.classification_report(yitest,ypred_gbc))
# Out:
# [[12309    19]
#  [  413   229]]
#               precision    recall  f1-score   support
#
#          0.0       0.97      1.00      0.98     12328
#          1.0       0.92      0.36      0.51       642
#
#     accuracy                           0.97     12970
#    macro avg       0.95      0.68      0.75     12970
# weighted avg       0.97      0.97      0.96     12970

# %%
rfe2=RFE(gbc,n_features_to_select=15)
rfe2.fit(Xitrain,yitrain)
gbc_rfe_df=pd.DataFrame({'Ranks':rfe2.ranking_},index=Xitrain.columns).sort_values('Ranks')
Xtrain_rfe2=Xitrain[gbc_rfe_df[gbc_rfe_df['Ranks']==1].index]
Xtest_rfe2=Xitest[gbc_rfe_df[gbc_rfe_df['Ranks']==1].index]

gbc_rfe=GradientBoostingClassifier()
gbc_rfe.fit(Xtrain_rfe2,yitrain)
ypred_gbc_rfe=gbc_rfe.predict(Xtest_rfe2)
print(metrics.confusion_matrix(yitest,ypred_gbc_rfe))
print(metrics.classification_report(yitest,ypred_gbc_rfe))
# Out:
# [[12311    17]
#  [  417   225]]
#               precision    recall  f1-score   support
#
#          0.0       0.97      1.00      0.98     12328
#          1.0       0.93      0.35      0.51       642
#
#     accuracy                           0.97     12970
#    macro avg       0.95      0.67      0.75     12970
# weighted avg       0.97      0.97      0.96     12970

# %%
print(metrics.roc_auc_score(ypred_gbc,yitest))
# Out:
# 0.9454618238154884

# %%
xgb.fit(Xtrain_rfe1,yitrain)
ypred_xgb1=xgb.predict(Xtest_rfe1)
print(metrics.confusion_matrix(yitest,ypred_xgb1))
print(metrics.classification_report(yitest,ypred_xgb1))
# Out:
# [[12316    12]
#  [  418   224]]
#               precision    recall  f1-score   support
#
#          0.0       0.97      1.00      0.98     12328
#          1.0       0.95      0.35      0.51       642
#
#     accuracy                           0.97     12970
#    macro avg       0.96      0.67      0.75     12970
# weighted avg       0.97      0.97      0.96     12970

# %%
rfe3=RFE(xgb,n_features_to_select=15)
rfe3.fit(Xitrain,yitrain)
xgb_rfe_df=pd.DataFrame({'Ranks':rfe3.ranking_},index=Xitrain.columns).sort_values('Ranks')
Xtrain_rfe3=Xitrain[xgb_rfe_df[xgb_rfe_df['Ranks']==1].index]
Xtest_rfe3=Xitest[xgb_rfe_df[xgb_rfe_df['Ranks']==1].index]

xgb_rfe=XGBClassifier()
xgb_rfe.fit(Xtrain_rfe3,yitrain)
ypred_xgb_rfe=xgb_rfe.predict(Xtest_rfe3)
print(metrics.confusion_matrix(yitest,ypred_xgb_rfe))
print(metrics.classification_report(yitest,ypred_xgb_rfe))
# Out:
# [[12318    10]
#  [  407   235]]
#               precision    recall  f1-score   support
#
#          0.0       0.97      1.00      0.98     12328
#          1.0       0.96      0.37      0.53       642
#
#     accuracy                           0.97     12970
#    macro avg       0.96      0.68      0.76     12970
# weighted avg       0.97      0.97      0.96     12970

# %%
stack_model2=VotingClassifier([('RF_rfe',rf_rfe),('XGB',xgb_rfe),('BBC',bbc)],voting='soft')
stack_model2.fit(Xtrain_rfe1,yitrain)
ypred_stack2=stack_model2.predict(Xtest_rfe1)
print(metrics.confusion_matrix(yitest,ypred_stack2))
print(metrics.classification_report(yitest,ypred_stack2))
# Out:
# [[12289    39]
#  [  328   314]]
#               precision    recall  f1-score   support
#
#          0.0       0.97      1.00      0.99     12328
#          1.0       0.89      0.49      0.63       642
#
#     accuracy                           0.97     12970
#    macro avg       0.93      0.74      0.81     12970
# weighted avg       0.97      0.97      0.97     12970

# %%
probs=stack_model2.predict_proba(Xtest_rfe1)[:,1] # keeping probability for class1

fpr,tpr,threshold=metrics.roc_curve(yitest,probs)
plt.plot([0,1],[0,1],linestyle='--')
plt.plot(fpr,tpr)
plt.title('ROC Curve')
plt.show()

prec,rec,threshold=metrics.precision_recall_curve(yitest,probs)
plt.plot([0, 1], [0.5, 0.5], linestyle='--')
plt.plot(prec,rec)
plt.title('Precision Recall Curve')
plt.show()

# %%
threshold
# Out:
# array([0.00343078, 0.00343096, 0.00343176, ..., 0.99275957, 0.99375665,
#        0.99424181])

# %% [markdown]
# # PCA

# %%
from sklearn.decomposition import PCA

# %% [markdown]
# #### PCA on imputed data

# %%
pca1=PCA()
pca1.fit(Xitrain,yitrain)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=None, random_state=None,
#     svd_solver='auto', tol=0.0, whiten=False)

# %%
from itertools import accumulate

# %%
plt.figure(figsize=(20,10))
plt.plot(pca1.explained_variance_ratio_,marker='x',label='variance')
plt.plot(list(accumulate(pca1.explained_variance_ratio_,lambda x,y:x+y)),marker='o',label='cumulative variance')
plt.legend()
plt.title('Scree Plot')
plt.show()

# %% [markdown]
# From the above scree plot, we will take optimum number of components as 8 or 9

# %%
pca_opt=PCA(n_components=10)
Xtrain_pca=pca_opt.fit_transform(Xitrain)
Xtest_pca=pca_opt.transform(Xitest)

# %%
dt_pca=DecisionTreeClassifier()
dt_pca.fit(Xtrain_pca,yitrain)
ypred_dt_pca=dt_pca.predict(Xtest_pca)
print(metrics.confusion_matrix(yitest,ypred_dt_pca))
print(metrics.classification_report(yitest,ypred_dt_pca))
# Out:
# [[11628   700]
#  [  553    89]]
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.94      0.95     12328
#          1.0       0.11      0.14      0.12       642
#
#     accuracy                           0.90     12970
#    macro avg       0.53      0.54      0.54     12970
# weighted avg       0.91      0.90      0.91     12970

# %% [markdown]
# #### PCA with rfe and imputed

# %%
pca2=PCA()
pca2.fit(Xtrain_rfe,yitrain)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=None, random_state=None,
#     svd_solver='auto', tol=0.0, whiten=False)

# %%
plt.figure(figsize=(20,10))
plt.plot(pca2.explained_variance_ratio_,marker='x',label='variance')
plt.plot(list(accumulate(pca2.explained_variance_ratio_,lambda x,y:x+y)),marker='o',label='cumulative variance')
plt.legend()
plt.title('Scree Plot')
plt.show()

# %% [markdown]
# From the above scree plot, we will take optimum number of components as 4 or 5

# %%
pca_opt1=PCA(n_components=5)
Xtrain_rfe_pca=pca_opt1.fit_transform(Xtrain_rfe)
Xtest_rfe_pca=pca_opt1.transform(Xtest_rfe)
dt_pca2=DecisionTreeClassifier()
dt_pca2.fit(Xtrain_rfe_pca,yitrain)
ypred_dt_rfe_pca=dt_pca2.predict(Xtest_rfe_pca)
print(metrics.confusion_matrix(yitest,ypred_dt_rfe_pca))
print(metrics.classification_report(yitest,ypred_dt_rfe_pca))
# Out:
# [[11670   658]
#  [  563    79]]
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.95      0.95     12328
#          1.0       0.11      0.12      0.11       642
#
#     accuracy                           0.91     12970
#    macro avg       0.53      0.53      0.53     12970
# weighted avg       0.91      0.91      0.91     12970

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()
Xtrain_rfe_ss=sc.fit_transform(Xtrain_rfe)
Xtest_rfe_ss=sc.fit_transform(Xtest_rfe)

# %%
Xtrain_rfe_pca_ss=pca_opt1.fit_transform(Xtrain_rfe_ss)
Xtest_rfe_pca_ss=pca_opt1.transform(Xtest_rfe_ss)
dt_pca3=DecisionTreeClassifier()
dt_pca3.fit(Xtrain_rfe_pca_ss,yitrain)
ypred_dt_rfe_pca_ss=dt_pca3.predict(Xtest_rfe_pca_ss)
print(metrics.confusion_matrix(yitest,ypred_dt_rfe_pca_ss))
print(metrics.classification_report(yitest,ypred_dt_rfe_pca_ss))
# Out:
# [[11603   725]
#  [  563    79]]
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.94      0.95     12328
#          1.0       0.10      0.12      0.11       642
#
#     accuracy                           0.90     12970
#    macro avg       0.53      0.53      0.53     12970
# weighted avg       0.91      0.90      0.91     12970

# %% [markdown]
# ## Hyper-Parameter Tuning

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold

# %%
params={'max_depth':range(1,20),'criterion':['entropy','gini']}
gs1=GridSearchCV(dt_rfe,params,cv=3,scoring='f1_weighted')
gs1.fit(Xtrain_rfe,yitrain)
gs1.best_params_
# Out:
# {'criterion': 'entropy', 'max_depth': 10}

# %%
dt_rfe_reg=DecisionTreeClassifier(max_depth=10,criterion='gini')
dt_rfe_reg.fit(Xtrain_rfe,yitrain)
print(metrics.confusion_matrix(yitest,dt_rfe_reg.predict(Xtest_rfe)))
print(metrics.classification_report(yitest,dt_rfe_reg.predict(Xtest_rfe)))
# Out:
# [[12207   121]
#  [  341   301]]
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.99      0.98     12328
#          1.0       0.71      0.47      0.57       642
#
#     accuracy                           0.96     12970
#    macro avg       0.84      0.73      0.77     12970
# weighted avg       0.96      0.96      0.96     12970

# %%
params={'max_depth':range(1,20),'criterion':['entropy','gini'],'n_estimators':range(1,20)}
gs2=GridSearchCV(rf_rfe,params,cv=3,scoring='f1_weighted')
gs2.fit(Xtrain_rfe,yitrain)
gs2.best_params_
# Out:
# {'criterion': 'gini', 'max_depth': 17, 'n_estimators': 18}

# %%
rf_rfe_reg=RandomForestClassifier(max_depth=17,criterion='entropy',n_estimators=15)
rf_rfe_reg.fit(Xtrain_rfe1,yitrain)
print(metrics.confusion_matrix(yitest,rf_rfe_reg.predict(Xtest_rfe1)))
print(metrics.classification_report(yitest,rf_rfe_reg.predict(Xtest_rfe1)))
# Out:
# [[12307    21]
#  [  400   242]]
#               precision    recall  f1-score   support
#
#          0.0       0.97      1.00      0.98     12328
#          1.0       0.92      0.38      0.53       642
#
#     accuracy                           0.97     12970
#    macro avg       0.94      0.69      0.76     12970
# weighted avg       0.97      0.97      0.96     12970

# %%
stack_model3=VotingClassifier([('BBC',bbc),('rf_reg',rf_rfe_reg)],voting='soft')
stack_model3.fit(Xtrain_rfe1,yitrain)
ypred_stack3=stack_model3.predict(Xtest_rfe1)
print(metrics.confusion_matrix(yitest,ypred_stack3))
print(metrics.classification_report(yitest,ypred_stack3))
# Out:
# [[12192   136]
#  [  263   379]]
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.99      0.98     12328
#          1.0       0.74      0.59      0.66       642
#
#     accuracy                           0.97     12970
#    macro avg       0.86      0.79      0.82     12970
# weighted avg       0.97      0.97      0.97     12970

# %%
probs=stack_model3.predict_proba(Xtest_rfe1)[:,1] # keeping probability for class1

fpr,tpr,threshold=metrics.roc_curve(yitest,probs)
plt.plot([0,1],[0,1],linestyle='--')
plt.plot(fpr,tpr)
plt.title('ROC Curve')
plt.show()

prec,rec,threshold=metrics.precision_recall_curve(yitest,probs)
plt.plot([0, 1], [0.5, 0.5], linestyle='--')
plt.plot(prec,rec)
plt.title('Precision Recall Curve')
plt.show()
